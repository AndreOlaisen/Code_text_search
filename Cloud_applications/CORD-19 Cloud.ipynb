# %%
import matplotlib.pyplot as plt
import numpy as np
from random import random
import time
import pickle

# %%
from vespa.package import Document, Field

document = Document(
    fields=[
        Field(name = "id", type = "string", indexing = ["attribute", "summary"]),
        Field(name = "title", type = "string", indexing = ["index", "summary"], index = "enable-bm25"),
        Field(name = "abstract", type = "string", indexing = ["index", "summary"], index = "enable-bm25"),
        Field(name = "body", type = "string", indexing = ["index", "summary"], index = "enable-bm25")#,
        #Field(name = "title_embedding", type = "tensor<float>(x[768]) ", indexing = ["attribute", "summary"])
    ]
)

# %%
from vespa.package import Schema, FieldSet, RankProfile

cord_19_schema = Schema(
    name = "cord_19",
    document = document,
    fieldsets = [FieldSet(name = "default", fields = ["title", "body"])],
    rank_profiles = [RankProfile(name = "default", first_phase = "nativeRank(title, body)"),
                    RankProfile(name = "bm25", first_phase = "bm25(title) + bm25(body)")]
)

# %%
from vespa.package import ApplicationPackage

app_package = ApplicationPackage(name = "cord_19", schema=cord_19_schema)

# %%
from vespa.package import VespaCloud

            #C:\Users\User\OneDrive - NTNU\NTNU\Prosjekt oppgave NLP
path_key = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\Cloud_test\\"
file = "andre.olaisen.tmartins-ntnu.pem"


# App name in Cloud
app_name = "andre-test-loud"
vespa_cloud = VespaCloud(
    tenant="tmartins-ntnu",
    application=app_name,
    key_location=path_key + file,
    application_package=app_package
)

# %%
name = "cord_19_application_simple"
path = path_key + name
print(path)
# Out:
# C:\Users\User\OneDrive - NTNU\NTNU\Prosjekt oppgave NLP\Cloud_test\cord_19_application

# %%
name = "cord_19_application_simple"

path_key = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\Cloud_test\\"


app = vespa_cloud.deploy(
    instance='andre-olaisen',
    disk_folder=path_key
)
# Out:
# Deployment started in run 51 of dev-aws-us-east-1c for tmartins-ntnu.andre-test-loud.andre-olaisen. This may take about 15 minutes the first time.
# INFO    [15:27:31]  Deploying platform version 7.314.13 and application version unknown ...
# WARNING [15:27:32]  tenant:tmartins-ntnu app:andre-test-loud:andre-olaisen Possibly destructive change 'content-cluster-removal' allowed
# INFO    [15:27:33]  Deployment successful.
# INFO    [15:27:33]  Session 3778 for tenant 'tmartins-ntnu' prepared and activated.
# INFO    [15:27:39]  ######## Details for all nodes ########
# INFO    [15:27:39]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:27:39]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:27:39]  --- storagenode on port 19102 has not started
# INFO    [15:27:39]  --- container-clustercontroller on port 19050 has not started
# INFO    [15:27:39]  --- searchnode on port 19107 has not started
# INFO    [15:27:39]  --- distributor on port 19111 has not started
# INFO    [15:27:39]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:27:39]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:27:39]  --- container on port 4080 has not started
# INFO    [15:27:39]  h5251c.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:27:39]  --- platform vespa/centos-tenant:7.314.13
# INFO    [15:27:39]  --- logserver-container on port 4080 has config generation 3778, wanted is 3778
# INFO    [15:28:06]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:28:06]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:28:06]  --- storagenode on port 19102 has not started
# INFO    [15:28:06]  --- container-clustercontroller on port 19050 has not started
# INFO    [15:28:06]  --- searchnode on port 19107 has not started
# INFO    [15:28:06]  --- distributor on port 19111 has not started
# INFO    [15:28:06]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:28:06]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:28:06]  --- container on port 4080 has not started
# INFO    [15:28:31]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:28:31]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:28:31]  --- storagenode on port 19102 has not started
# INFO    [15:28:31]  --- container-clustercontroller on port 19050 has not started
# INFO    [15:28:31]  --- searchnode on port 19107 has not started
# INFO    [15:28:31]  --- distributor on port 19111 has not started
# INFO    [15:28:31]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:28:31]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:28:31]  --- container on port 4080 has not started
# INFO    [15:29:00]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:29:00]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:29:00]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:29:00]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:29:30]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:29:30]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:29:30]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:29:30]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:30:01]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:30:01]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:30:01]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:30:01]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:30:30]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:30:30]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:30:30]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:30:30]  --- platform vespa/centos-tenant:7.314.13 <-- :
# INFO    [15:31:00]  Found endpoints:
# INFO    [15:31:00]  - dev.aws-us-east-1c
# INFO    [15:31:00]   |-- https://cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ (cluster 'cord_19_container')
# INFO    [15:31:02]  Installation succeeded!

# %%
from pandas import read_csv

path = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\dataset\\CORD-19\\"
docs = read_csv(path + "crod_19_only_rel.csv")
docs.shape
# Out:
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (37279, 21)

# %%
docs.head()
# Out:
#    Unnamed: 0  cord_uid                                       sha source_x  \
# 0           3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 1           5  zjufx4fo  b2897e1277f56641193a6db73825f707eed3e4c9      PMC
# 2           7  8zchiykl  5806726a24dc91de3954001effbdffd7a82d54e2      PMC
# 3          10  5tkvsudh  9d4e3e8eb092d5ed282d0aa4aadcaa8b7165b5e9      PMC
# 4          12  tvxpckxo  d09b79026117ec9faebba46a8d13aa9b23ec751e      PMC
#
#                                                title  \
# 0               Role of endothelin-1 in lung disease
# 1  Sequence requirements for RNA strand transfer ...
# 2  The 21st International Symposium on Intensive ...
# 3  Conservation of polyamine regulation by transl...
# 4  A Method to Identify p62's UBA Domain Interact...
#
#                         doi      pmcid   pubmed_id   license  \
# 0              10.1186/rr44   PMC59574  11686871.0     no-cc
# 1  10.1093/emboj/20.24.7220  PMC125340  11742998.0  green-oa
# 2            10.1186/cc1013  PMC137274  11353930.0     no-cc
# 3   10.1093/emboj/19.8.1907  PMC302018  10775274.0     no-cc
# 4             10.1251/bpo66  PMC302190  14702098.0     no-cc
#
#                                             abstract  ...  \
# 0  Endothelin-1 (ET-1) is a 21 amino acid peptide...  ...
# 1  Nidovirus subgenomic mRNAs contain a leader se...  ...
# 2  The 21st International Symposium on Intensive ...  ...
# 3  Regulation of ornithine decarboxylase in verte...  ...
# 4  The UBA domain is a conserved sequence motif a...  ...
#
#                                              authors             journal  \
# 0  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M          Respir Res
# 1  Pasternak, Alexander O.; van den Born, Erwin; ...    The EMBO Journal
# 2                      Ball, Jonathan; Venn, Richard           Crit Care
# 3  Ivanov, Ivaylo P.; Matsufuji, Senya; Murakami,...              EMBO J
# 4  Pridgeon, Julia W.; Geetha, Thangiah; Wooten, ...  Biol Proced Online
#
#   mag_id  who_covidence_id arxiv_id  \
# 0    NaN               NaN      NaN
# 1    NaN               NaN      NaN
# 2    NaN               NaN      NaN
# 3    NaN               NaN      NaN
# 4    NaN               NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 1  document_parses/pdf_json/b2897e1277f56641193a6...
# 2  document_parses/pdf_json/5806726a24dc91de39540...
# 3  document_parses/pdf_json/9d4e3e8eb092d5ed282d0...
# 4  document_parses/pdf_json/d09b79026117ec9faebba...
#
#                                 pmc_json_files  \
# 0   document_parses/pmc_json/PMC59574.xml.json
# 1  document_parses/pmc_json/PMC125340.xml.json
# 2  document_parses/pmc_json/PMC137274.xml.json
# 3  document_parses/pmc_json/PMC302018.xml.json
# 4  document_parses/pmc_json/PMC302190.xml.json
#
#                                                  url s2_id  \
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...   NaN
# 1  http://europepmc.org/articles/pmc125340?pdf=re...   NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...   NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   NaN
#
#                                            body_text
# 0  from xenopus laevis [16] . eta receptors in no...
# 1  the genetic information of rna viruses is orga...
# 2  this year's symposium was dominated by the res...
# 3  the ef®ciency of +1 ribosomal frameshifting at...
# 4  p62 is a novel cellular protein which was init...
#
# [5 rows x 21 columns]

# %%
start = time.time()
m = start
i = 0
for idx, row in docs.iterrows():
    if idx > 36000:
        if (i % 1000 == 0):
            # Each loop about 10 min or 600 s
            print(i," : " ,idx)
            print("Time:", round(time.time() - m,1))
            m = time.time()
        i += 1
        #print(len(row["title"]), end = "  ")
        response = app.feed_data_point(
            schema = "cord_19",
            data_id = str(row["cord_uid"]),
            fields = {
                "id": str(row["cord_uid"]),
                "title": str(row["title"]),
                "abstract": str(row["abstract"]),
                "body": str(row["body_text"])
            }
        )
# Out:
# 0  :  36001
# Time: 5.7
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1670         else:
# -> 1671             _raise_current_error()
#    1672
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'ssl3_read_bytes', 'sslv3 alert certificate unknown')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     490             except OpenSSL.SSL.Error as e:
# --> 491                 raise ssl.SSLError("bad handshake: %r" % e)
#     492             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'ssl3_read_bytes', 'sslv3 alert certificate unknown')])",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud', port=443): Max retries exceeded with url: //document/v1/cord_19/cord_19/docid/co0nk7pt (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_read_bytes', 'sslv3 alert certificate unknown')])")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-18-95a58cfecd2d> in <module>
#      18                 "title": str(row["title"]),
#      19                 "abstract": str(row["abstract"]),
# ---> 20                 "body": str(row["body_text"])
#      21             }
#      22         )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\vespa\application.py in feed_data_point(self, schema, data_id, fields)
#     126         )
#     127         vespa_format = {"fields": fields}
# --> 128         response = post(end_point, json=vespa_format, cert=self.cert)
#     129         return response
#     130
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud', port=443): Max retries exceeded with url: //document/v1/cord_19/cord_19/docid/co0nk7pt (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_read_bytes', 'sslv3 alert certificate unknown')])")))

# %%
labeled_data = [
    {
        'query_id': 1,
        'query': 'coronavirus origin',
        'relevant_docs': [{'id': '005b2j4b', 'score': 2}, {'id': '00fmeepz', 'score': 1}]
    },
    {
        'query_id': 2,
        'query': 'coronavirus response to weather changes',
        'relevant_docs': [{'id': '01goni72', 'score': 2}, {'id': '03h85lvy', 'score': 2}]
    }
]

# %% [markdown]
# ### Loading labeled data

# %%
path = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\dataset\\CORD-19\\"

labeled_data = []
with open(path + "labeled_data_cord_19.txt", "rb") as fp:   # Unpickling
    labeled_data = pickle.load(fp)

# %%
from vespa.query import Query, OR, AND, WeakAnd, ANN, RankProfile as Ranking


results = app.query(
    query="Where is my app",
    query_model = Query(
        match_phase=AND(),
        rank_profile=Ranking(name="default")
    ),
    hits = 10
)

# %%
len(results.hits)
for result in results.hits:
    print(result["id"], "  ", result["fields"]["title"])
