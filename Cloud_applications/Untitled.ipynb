# %%
import matplotlib.pyplot as plt
import numpy as np
from random import random
import time

# %%
from vespa.package import Document, Field

document = Document(
    fields=[
        Field(name = "id", type = "string", indexing = ["attribute", "summary"]),
        Field(name = "title", type = "string", indexing = ["index", "summary"], index = "enable-bm25"),
        Field(name = "abstract", type = "string", indexing = ["index", "summary"], index = "enable-bm25"),
        Field(name = "body", type = "string", indexing = ["index", "summary"], index = "enable-bm25")#,
        #Field(name = "title_embedding", type = "tensor<float>(x[768]) ", indexing = ["attribute", "summary"])
    ]
)

# %%
from vespa.package import Schema, FieldSet, RankProfile

cord_19_schema = Schema(
    name = "cord_19",
    document = document,
    fieldsets = [FieldSet(name = "default", fields = ["title", "body"])],
    rank_profiles = [RankProfile(name = "default", first_phase = "nativeRank(title, body)"),
                    RankProfile(name = "bm25", first_phase = "bm25(title) + bm25(body)")]
)

# %%
from vespa.package import ApplicationPackage

app_package = ApplicationPackage(name = "cord_19", schema=cord_19_schema)

# %%
from vespa.package import VespaCloud

            #C:\Users\User\OneDrive - NTNU\NTNU\Prosjekt oppgave NLP
path_key = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\Cloud_test\\"
file = "andre.olaisen.tmartins-ntnu.pem"


# App name in Cloud
app_name = "andre-test-loud"
vespa_cloud = VespaCloud(
    tenant="tmartins-ntnu",
    application=app_name,
    key_location=path_key + file,
    application_package=app_package
)

# %%
name = "cord_19_application"
path = path_key + name
print(path)
# Out:
# C:\Users\User\OneDrive - NTNU\NTNU\Prosjekt oppgave NLP\Cloud_test\cord_19_application

# %%
name = "sample_application"

path_key = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\Cloud_test\\"


app = vespa_cloud.deploy(
    instance='andre-olaisen',
    disk_folder=path_key
)
# Out:
# Deployment started in run 46 of dev-aws-us-east-1c for tmartins-ntnu.andre-test-loud.andre-olaisen. This may take about 15 minutes the first time.
# INFO    [15:56:46]  Deploying platform version 7.312.45 and application version unknown ...
# INFO    [15:56:49]  Deployment successful.
# INFO    [15:56:49]  Session 3607 for tenant 'tmartins-ntnu' prepared and activated.
# INFO    [15:56:59]  ######## Details for all nodes ########
# INFO    [15:57:34]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:57:34]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:57:34]  --- container on port 4080 has not started
# INFO    [15:57:34]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:57:34]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:57:34]  --- searchnode on port 19107 has not started
# INFO    [15:57:34]  --- distributor on port 19111 has not started
# INFO    [15:57:34]  --- storagenode on port 19102 has not started
# INFO    [15:57:34]  --- container-clustercontroller on port 19050 has not started
# INFO    [15:57:34]  h5251c.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:57:34]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:57:34]  --- logserver-container on port 4080 has not started
# INFO    [15:58:00]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:58:00]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:58:00]  --- container on port 4080 has not started
# INFO    [15:58:00]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:58:00]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:58:00]  h5251c.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:58:00]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:58:30]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:58:30]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:58:30]  h5251b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:58:30]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:58:30]  h5251c.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:58:30]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:59:00]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:59:00]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:59:00]  h5251c.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:59:00]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:59:30]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:59:30]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [15:59:30]  h5251c.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [15:59:30]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [16:00:01]  h5250l.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [16:00:01]  --- platform vespa/centos-tenant:7.312.45 <-- :
# INFO    [16:00:30]  Found endpoints:
# INFO    [16:00:30]  - dev.aws-us-east-1c
# INFO    [16:00:30]   |-- https://cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ (cluster 'cord_19_container')
# INFO    [16:00:35]  Failed to get 100 consecutive OKs from endpoint https://cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ [scope=zone, legacy=false, routingMethod=exclusive]
# INFO    [16:01:00]  Found endpoints:
# INFO    [16:01:00]  - dev.aws-us-east-1c
# INFO    [16:01:00]   |-- https://cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ (cluster 'cord_19_container')
# INFO    [16:01:05]  Failed to get 100 consecutive OKs from endpoint https://cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ [scope=zone, legacy=false, routingMethod=exclusive]
# INFO    [16:01:30]  Found endpoints:
# INFO    [16:01:30]  - dev.aws-us-east-1c
# INFO    [16:01:30]   |-- https://cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ (cluster 'cord_19_container')
# INFO    [16:01:35]  Failed to get 100 consecutive OKs from endpoint https://cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ [scope=zone, legacy=false, routingMethod=exclusive]
# INFO    [16:02:00]  Found endpoints:
# INFO    [16:02:00]  - dev.aws-us-east-1c
# INFO    [16:02:00]   |-- https://cord-19-container.andre-olaisen.andre-test-loud.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ (cluster 'cord_19_container')
# INFO    [16:02:02]  Installation succeeded!

# %%
from pandas import read_csv

path = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\dataset\\CORD-19\\"
docs = read_csv(path + "crod_19_only_rel.csv")
docs.shape
# Out:
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (37279, 21)

# %%
docs.head()
# Out:
#    Unnamed: 0  cord_uid                                       sha source_x  \
# 0           3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 1           5  zjufx4fo  b2897e1277f56641193a6db73825f707eed3e4c9      PMC
# 2           7  8zchiykl  5806726a24dc91de3954001effbdffd7a82d54e2      PMC
# 3          10  5tkvsudh  9d4e3e8eb092d5ed282d0aa4aadcaa8b7165b5e9      PMC
# 4          12  tvxpckxo  d09b79026117ec9faebba46a8d13aa9b23ec751e      PMC
#
#                                                title  \
# 0               Role of endothelin-1 in lung disease
# 1  Sequence requirements for RNA strand transfer ...
# 2  The 21st International Symposium on Intensive ...
# 3  Conservation of polyamine regulation by transl...
# 4  A Method to Identify p62's UBA Domain Interact...
#
#                         doi      pmcid   pubmed_id   license  \
# 0              10.1186/rr44   PMC59574  11686871.0     no-cc
# 1  10.1093/emboj/20.24.7220  PMC125340  11742998.0  green-oa
# 2            10.1186/cc1013  PMC137274  11353930.0     no-cc
# 3   10.1093/emboj/19.8.1907  PMC302018  10775274.0     no-cc
# 4             10.1251/bpo66  PMC302190  14702098.0     no-cc
#
#                                             abstract  ...  \
# 0  Endothelin-1 (ET-1) is a 21 amino acid peptide...  ...
# 1  Nidovirus subgenomic mRNAs contain a leader se...  ...
# 2  The 21st International Symposium on Intensive ...  ...
# 3  Regulation of ornithine decarboxylase in verte...  ...
# 4  The UBA domain is a conserved sequence motif a...  ...
#
#                                              authors             journal  \
# 0  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M          Respir Res
# 1  Pasternak, Alexander O.; van den Born, Erwin; ...    The EMBO Journal
# 2                      Ball, Jonathan; Venn, Richard           Crit Care
# 3  Ivanov, Ivaylo P.; Matsufuji, Senya; Murakami,...              EMBO J
# 4  Pridgeon, Julia W.; Geetha, Thangiah; Wooten, ...  Biol Proced Online
#
#   mag_id  who_covidence_id arxiv_id  \
# 0    NaN               NaN      NaN
# 1    NaN               NaN      NaN
# 2    NaN               NaN      NaN
# 3    NaN               NaN      NaN
# 4    NaN               NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 1  document_parses/pdf_json/b2897e1277f56641193a6...
# 2  document_parses/pdf_json/5806726a24dc91de39540...
# 3  document_parses/pdf_json/9d4e3e8eb092d5ed282d0...
# 4  document_parses/pdf_json/d09b79026117ec9faebba...
#
#                                 pmc_json_files  \
# 0   document_parses/pmc_json/PMC59574.xml.json
# 1  document_parses/pmc_json/PMC125340.xml.json
# 2  document_parses/pmc_json/PMC137274.xml.json
# 3  document_parses/pmc_json/PMC302018.xml.json
# 4  document_parses/pmc_json/PMC302190.xml.json
#
#                                                  url s2_id  \
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...   NaN
# 1  http://europepmc.org/articles/pmc125340?pdf=re...   NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...   NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   NaN
#
#                                            body_text
# 0  from xenopus laevis [16] . eta receptors in no...
# 1  the genetic information of rna viruses is orga...
# 2  this year's symposium was dominated by the res...
# 3  the ef®ciency of +1 ribosomal frameshifting at...
# 4  p62 is a novel cellular protein which was init...
#
# [5 rows x 21 columns]

# %%
start = time.time()
m = start
i = 1
for idx, row in docs.iterrows():
    i += 1
    if (i % 1000 == 0):
        # Each loop about 10 min or 600 s
        print(i," : " ,idx)
        print("Time:", round(time.time() - m,1))
        m = time.time()
    #print(len(row["title"]), end = "  ")
    response = app.feed_data_point(
        schema = "cord_19",
        data_id = str(row["cord_uid"]),
        fields = {
            "id": str(row["cord_uid"]),
            "title": str(row["title"]),
            "abstract": str(row["abstract"]),
            "body": str(row["body_text"])
        }
    )
# Out:
# 100
# Time: 65.7
# 200
# Time: 67.5
# 300
# Time: 67.4
# 400
# Time: 67.2
# 500
# Time: 73.2
# 600
# Time: 65.8
# 700
# Time: 72.4
# 800
# Time: 65.9
# 900
# Time: 72.5
# 1000
# Time: 70.0
# 1100
# Time: 69.1
# 1200
# Time: 70.1
# 1300
# Time: 75.5
# 1400
# Time: 56.6
# 1500
# Time: 57.2
# 1600
# Time: 82.5
# 1700
# Time: 65.4
# 1800
# Time: 65.4
# 1900
# Time: 98.6
# 2000
# Time: 94.3
# 2100
# Time: 77.9
# 2200
# Time: 75.5
# 22800
# Time: 61.2
# 22900
# Time: 62.6
# 23000
# Time: 60.9
# 23100
# Time: 59.9
# 23200
# Time: 59.3
# 23300
# Time: 81.7
# 23400
# Time: 64.4
# 23500
# Time: 70.1
# 23600
# Time: 59.4
# 23700
# Time: 60.4
# 23800
# Time: 61.3
# 23900
# Time: 62.4
# 24000
# Time: 62.8
# 24100
# Time: 59.7
# 24200
# Time: 56.8
# 24300
# Time: 64.5
# 24400
# Time: 63.9
# 24500
# Time: 59.7
# 24600
# Time: 59.8
# 24700
# Time: 61.4
# 24800
# Time: 61.1
# 24900
# Time: 59.6
# 25000
# Time: 60.6
# 25100
# Time: 61.2
# 25200
# Time: 58.4
# 25300
# Time: 63.8
# 25400
# Time: 74.3
# 25500
# Time: 61.4
# 25600
# Time: 63.4
# 25700
# Time: 61.9
# 25800
# Time: 64.0
# 25900
# Time: 60.1
# 26000
# Time: 61.3
# 26100
# Time: 63.3
# 26200
# Time: 60.3
# 26300
# Time: 61.4
# 26400
# Time: 61.8
# 26500
# Time: 59.1
# 26600
# Time: 61.6
# 26700
# Time: 64.0
# 26800
# Time: 60.1
# 26900
# Time: 63.1
# 27000
# Time: 61.3
# 27100
# Time: 65.7
# 27200
# Time: 62.5
# 27300
# Time: 59.8
# 27400
# Time: 59.6
# 27500
# Time: 60.1
# 27600
# Time: 58.6
# 27700
# Time: 61.9
# 27800
# Time: 58.7
# 27900
# Time: 60.0
# 28000
# Time: 62.5
# 28100
# Time: 58.3
# 28200
# Time: 61.7
# 28300
# Time: 60.9
# 28400
# Time: 58.4
# 28500
# Time: 59.9
# 28600
# Time: 59.2
# 28700
# Time: 61.5
# 28800
# Time: 60.4
# 28900
# Time: 60.7
# 29000
# Time: 63.5
# 29100
# Time: 62.3
# 29200
# Time: 62.9
# 29300
# Time: 60.2
# 29400
# Time: 61.0
# 29500
# Time: 57.9
# 29600
# Time: 60.0
# 29700
# Time: 61.6
# 29800
# Time: 58.4
# 29900
# Time: 60.3
# 30000
# Time: 60.5
# 30100
# Time: 61.1
# 30200
# Time: 66.2
# 30300
# Time: 74.5
# 30400
# Time: 67.1
# 30500
# Time: 75.3
# 30600
# Time: 58.8

# %%
labeled_data = [
    {
        'query_id': 1,
        'query': 'coronavirus origin',
        'relevant_docs': [{'id': '005b2j4b', 'score': 2}, {'id': '00fmeepz', 'score': 1}]
    },
    {
        'query_id': 2,
        'query': 'coronavirus response to weather changes',
        'relevant_docs': [{'id': '01goni72', 'score': 2}, {'id': '03h85lvy', 'score': 2}]
    }
]

# %% [markdown]
# ### Loading labeled data

# %%
path = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\dataset\\CORD-19\\"

labeled_data = []
with open(path + "labeled_data_cord_19.txt", "rb") as fp:   # Unpickling
    labeled_data = pickle.load(fp)
